# %%
print("I am in ms_python environment")
print("I do not see markdown in the pressent view of jupyter notebook")
# Out:
# I am in ms_python environment
# I do not see markdown in the pressent view of jupyter notebook

# %%
def addition_function(x, y):
    return x+y
result = addition_function(5, 7)
print(f"The result of addition of 5 and 7 is {result})")
# Out:
# The result of addition of 5 and 7 is 12)
