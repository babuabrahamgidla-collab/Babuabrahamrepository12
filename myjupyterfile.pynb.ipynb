# %%
print("Hello, World!")
print("This is a sample Python script.")
print("I am struggling to get going with jupyter notebooks.")
print("I am determined to learn and improve my skills.")
print("Let's keep pushing forward and exploring new concepts together!")
# Out:
# Hello, World!
# This is a sample Python script.
# I am struggling to get going with jupyter notebooks.
# I am determined to learn and improve my skills.
# Let's keep pushing forward and exploring new concepts together!

# %% [markdown]
# Markdown is I am struggling to understand how to use jupyter notebook

# %%
from datetime import datetime 
print("Current date and time: ", datetime.now())
# Out:
# Current date and time:  2026-09-16 21:03:47.294650
